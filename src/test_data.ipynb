# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'/Users/ishantchaudhary/REPOS/Master Thesis Bond Prices Prediction/data/raw/mergedissue.csv')
# Out:
# /var/folders/4b/l73ksqn90ls5dx9x6n2k93xc0000gn/T/ipykernel_26146/2123306991.py:1: DtypeWarning: Columns (9,28,43,44,49,57,58,64,82,86,98,99,100,101,102,107,108,109,112,113,117,127,128,129,130,131,132,133,134,135,136,137,138,139,141,144,146,147,148,149,162,163,168,190,191,192,193,194,196,197,200,201,202,204,205,221) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'/Users/ishantchaudhary/REPOS/Master Thesis Bond Prices Prediction/data/raw/mergedissue.csv')

# %%
data.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'issue_id',
#  'issuer_id',
#  'prospectus_issuer_name',
#  'issuer_cusip',
#  'issue_cusip',
#  'issue_name',
#  'maturity',
#  'security_level',
#  'security_pledge',
#  'enhancement',
#  'coupon_type',
#  'convertible',
#  'mtn',
#  'asset_backed',
#  'yankee',
#  'canadian',
#  'oid',
#  'foreign_currency',
#  'slob',
#  'issue_offered_global',
#  'settlement_type',
#  'gross_spread',
#  'selling_concession',
#  'reallowance',
#  'comp_neg_exch_deal',
#  'rule_415_reg',
#  'sec_reg_type1',
#  'sec_reg_type2',
#  'rule_144a',
#  'treasury_spread',
#  'treasury_maturity',
#  'offering_amt',
#  'offering_date',
#  'offering_price',
#  'offering_yield',
#  'delivery_date',
#  'unit_deal',
#  'form_of_own',
#  'denomination',
#  'principal_amt',
#  'covenants',
#  'defeased',
#  'defeasance_type',
#  'defeased_date',
#  'defaulted',
#  'tender_exch_offer',
#  'redeemable',
#  'refund_protection',
#  'refunding_date',
#  'putable',
#  'overallotment_opt',
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  issue_id  issuer_id   prospectus_issuer_name issuer_cusip  \
# 0           0       1.0        3.0                 AAR CORP       000361
# 1           1       2.0        3.0                 AAR CORP       000361
# 2           2       3.0    40263.0  ABN AMRO BK N V N Y BRH       00077D
# 3           3       4.0    40263.0  ABN AMRO BK N V N Y BRH       00077D
# 4           4       5.0    40263.0  ABN AMRO BK N V N Y BRH       00077T
#
#   issue_cusip        issue_name    maturity security_level security_pledge  \
# 0         AA3                NT  2001-11-01            SEN             NaN
# 1         AB1                NT  2003-10-15            SEN             NaN
# 2         AB5               MTN  1996-01-12            SEN             NaN
# 3         AF6  SUB DEP NT SER B  2009-08-01           SENS             NaN
# 4         AA2  SUB DEP NT SER B  2023-05-15            SUB             NaN
#
#    ... subsidiary_redesignation subsidiary_guarantee sales_leaseback_sub  \
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0      issue_id      issuer_id   gross_spread  \
# count  561184.000000  5.611840e+05  561184.000000  212529.000000
# mean   226078.185294  5.095705e+05   18680.761978       4.763116
# std    152552.603423  3.218243e+05   18509.958403     121.878155
# min         0.000000  1.000000e+00       3.000000       0.000000
# 25%     79111.750000  1.669558e+05    1489.000000       0.750000
# 50%    219407.500000  5.533950e+05    5099.000000       1.800000
# 75%    359703.250000  7.543325e+05   37581.000000       4.500000
# max    499999.000000  1.042557e+06   51760.000000   45000.000000
#
#        selling_concession   reallowance  treasury_spread  offering_amt  \
# count       148125.000000  6.950900e+04     63141.000000  5.611230e+05
# mean             2.905805  2.153545e+03       138.419537  3.489514e+05
# std             94.160064  5.672672e+05       181.080736  6.665280e+06
# min              0.000000  0.000000e+00      -292.000000  0.000000e+00
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(data, minimal=True)
profile.to_file("bond_pricing_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
